# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# load data
data = pd.read_csv("anomaly_scores.csv")
data.head()
# Out:
#              timestamp  count  anomaly_score
# 0  2005-01-30 00:00:00     12          1.000
# 1  2005-02-06 00:00:00     19          1.000
# 2  2005-02-13 00:00:00     28          1.000
# 3  2005-02-20 00:00:00     47          0.750
# 4  2005-02-27 00:00:00     64          0.525

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'])

# %%
fig, ax = plt.subplots(figsize=(20,12))
ax2 = ax.twinx()

# plot count in blue
ax.plot(data.timestamp, data["count"], c='b')
ax.set_xlabel('date (week)')
ax.set_ylabel('count')

# plot anomaly score in red
ax2.plot(data.timestamp, data.anomaly_score, c='r')
ax2.set_ylabel('anomaly score')

# %%
"""
Hohe anomaly score am Anfang ist normal, da alles neu ist.

In den letzten Jahren scheinen anomalies nicht mehr erkannt zu werden. Könnte auch ein Gewöhnungseffekt sein.
Das lässt sich bestimmt in den Parametern anpassen.
"""
